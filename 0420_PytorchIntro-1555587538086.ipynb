# %% [markdown]
# ## Outline
# * PyTorch
# * What are tensors
# * Initialising, slicing, reshaping tensors
# * Numpy and PyTorch interfacing
# * GPU support for PyTorch + Enabling GPUs on Google Colab
# * Speed comparisons, Numpy -- PyTorch -- PyTorch on GPU
# * Autodiff concepts and application
# * Writing a basic learning loop using autograd
# * Exercises

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialise tensors

# %%
x = torch.ones(3, 2)
print(x)
x = torch.zeros(3, 2)
print(x)
x = torch.rand(3, 2)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# tensor([[0.2870, 0.8413],
#         [0.7797, 0.8250],
#         [0.2220, 0.6147]])

# %%
x = torch.empty(3, 2)
print(x)
y = torch.zeros_like(x)
print(y)
# Out:
# tensor([[1.4197e-36, 0.0000e+00],
#         [3.3631e-44, 0.0000e+00],
#         [       nan, 0.0000e+00]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
x = torch.linspace(0, 1, steps=5)
print(x)
# Out:
# tensor([0.0000, 0.2500, 0.5000, 0.7500, 1.0000])

# %%
x = torch.tensor([[1, 2], 
                 [3, 4], 
                 [5, 6]])
print(x)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %% [markdown]
# ## Slicing tensors

# %%
print(x.size())
print(x[:, 1]) 
print(x[0, :])
# Out:
# torch.Size([3, 2])
# tensor([2, 4, 6])
# tensor([1, 2])

# %%
y = x[1, 1]
print(y)
print(y.item())
# Out:
# tensor(4)
# 4

# %% [markdown]
# ## Reshaping tensors

# %%
print(x)
y = x.view(2, 3)
print(y)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
y = x.view(6,-1) 
print(y)
# Out:
# tensor([[1],
#         [2],
#         [3],
#         [4],
#         [5],
#         [6]])

# %% [markdown]
# ## Simple Tensor Operations

# %%
x = torch.ones([3, 2])
y = torch.ones([3, 2])
z = x + y
print(z)
z = x - y
print(z)
z = x * y
print(z)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
z = y.add(x)
print(z)
print(y)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
z = y.add_(x)
print(z)
print(y)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])

# %% [markdown]
# ## Numpy <> PyTorch

# %%
x_np = x.numpy()
print(type(x), type(x_np))
print(x_np)
# Out:
# <class 'torch.Tensor'> <class 'numpy.ndarray'>
# [[1. 1.]
#  [1. 1.]
#  [1. 1.]]

# %%
a = np.random.randn(5)
print(a)
a_pt = torch.from_numpy(a)
print(type(a), type(a_pt))
print(a_pt)
# Out:
# [-0.05945781 -1.23573237  0.86881041 -1.65728807  0.74395251]
# <class 'numpy.ndarray'> <class 'torch.Tensor'>
# tensor([-0.0595, -1.2357,  0.8688, -1.6573,  0.7440], dtype=torch.float64)

# %%
np.add(a, 1, out=a)
print(a)
print(a_pt)
# Out:
# [ 0.94054219 -0.23573237  1.86881041 -0.65728807  1.74395251]
# tensor([ 0.9405, -0.2357,  1.8688, -0.6573,  1.7440], dtype=torch.float64)

# %%
# %%time
for i in range(100):
  a = np.random.randn(100,100)
  b = np.random.randn(100,100)
  c = np.matmul(a, b)
# Out:
# CPU times: user 179 ms, sys: 92.7 ms, total: 272 ms
# Wall time: 148 ms

# %%
# %%time
for i in range(100):
  a = torch.randn([100, 100])
  b = torch.randn([100, 100])
  c = torch.matmul(a, b)
# Out:
# CPU times: user 67.2 ms, sys: 55.8 ms, total: 123 ms
# Wall time: 80.8 ms

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  c = a + b
# Out:
# CPU times: user 1min 30s, sys: 1.56 s, total: 1min 31s
# Wall time: 1min 31s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000])
  b = torch.randn([10000, 10000])
  c = a + b
# Out:
# CPU times: user 24 s, sys: 113 ms, total: 24.1 s
# Wall time: 24.1 s

# %% [markdown]
# ## CUDA support

# %%
print(torch.cuda.device_count())
# Out:
# 1

# %%
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# <torch.cuda.device object at 0x7fd2d8bd2b38>
# Tesla K80

# %%
cuda0 = torch.device('cuda:0')

# %%
a = torch.ones(3, 2, device=cuda0)
b = torch.ones(3, 2, device=cuda0)
c = a + b
print(c)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]], device='cuda:0')

# %%
print(a)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]], device='cuda:0')

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  np.add(b, a)
# Out:
# CPU times: user 1min 31s, sys: 554 ms, total: 1min 32s
# Wall time: 1min 32s

# %%
# %%time
for i in range(10):
  a_cpu = torch.randn([10000, 10000])
  b_cpu = torch.randn([10000, 10000])
  b_cpu.add_(a_cpu)
# Out:
# CPU times: user 23.8 s, sys: 49.9 ms, total: 23.8 s
# Wall time: 23.8 s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000], device=cuda0)
  b = torch.randn([10000, 10000], device=cuda0)
  b.add_(a)
# Out:
# CPU times: user 2.28 ms, sys: 13 ms, total: 15.3 ms
# Wall time: 21.7 ms

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  np.matmul(b, a)
# Out:
# CPU times: user 25min 28s, sys: 10.3 s, total: 25min 38s
# Wall time: 13min 45s

# %%
# %%time
for i in range(10):
  a_cpu = torch.randn([10000, 10000])
  b_cpu = torch.randn([10000, 10000])
  torch.matmul(a_cpu, b_cpu)
# Out:
# CPU times: user 4min 59s, sys: 449 ms, total: 5min
# Wall time: 5min

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000], device=cuda0)
  b = torch.randn([10000, 10000], device=cuda0)
  torch.matmul(a, b)
# Out:
# CPU times: user 12.1 ms, sys: 28 ms, total: 40.1 ms
# Wall time: 53.9 ms

# %% [markdown]
# ## Autodiff

# %%
x = torch.ones([3, 2], requires_grad=True)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]], requires_grad=True)

# %%
y = x + 5
print(y)
# Out:
# tensor([[6., 6.],
#         [6., 6.],
#         [6., 6.]], grad_fn=<AddBackward0>)

# %%
z = y*y + 1
print(z)
# Out:
# tensor([[37., 37.],
#         [37., 37.],
#         [37., 37.]], grad_fn=<AddBackward0>)

# %%
t = torch.sum(z)
print(t)
# Out:
# tensor(222., grad_fn=<SumBackward0>)

# %%
t.backward()

# %%
print(x.grad)
# Out:
# tensor([[12., 12.],
#         [12., 12.],
#         [12., 12.]])

# %% [markdown]
# $t = \sum_i z_i, z_i = y_i^2 + 1, y_i = x_i + 5$
#
# $\frac{\partial t}{\partial x_i} = \frac{\partial z_i}{\partial x_i} = \frac{\partial z_i}{\partial y_i} \frac{\partial y_i}{\partial x_i} = 2y_i \times 1$
#
#
# At x = 1, y = 6, $\frac{\partial t}{\partial x_i} = 12$

# %%
x = torch.ones([3, 2], requires_grad=True)
y = x + 5
print(y)
r = 1/(1 + torch.exp(-y))
print(r)
s = torch.sum(r)
print(s)
s.backward()
print(s)
print(x.grad)
# Out:
# tensor([[6., 6.],
#         [6., 6.],
#         [6., 6.]], grad_fn=<AddBackward0>)
# tensor([[0.9975, 0.9975],
#         [0.9975, 0.9975],
#         [0.9975, 0.9975]], grad_fn=<MulBackward0>)
# tensor(5.9852, grad_fn=<SumBackward0>)
# tensor(5.9852, grad_fn=<SumBackward0>)
# tensor([[0.0025, 0.0025],
#         [0.0025, 0.0025],
#         [0.0025, 0.0025]])

# %%
x = torch.ones([3, 2], requires_grad=True)
y = x + 5
r = 1/(1 + torch.exp(-y))
a = torch.ones([3, 2])
r.backward(a)
print(x.grad)
# Out:
# tensor([[0.0025, 0.0025],
#         [0.0025, 0.0025],
#         [0.0025, 0.0025]])

# %% [markdown]
# $\frac{\partial{s}}{\partial{x}} = \frac{\partial{s}}{\partial{r}} \cdot \frac{\partial{r}}{\partial{x}}$
#
# For the above code $a$ represents $\frac{\partial{s}}{\partial{r}}$ and then $x.grad$ gives directly $\frac{\partial{s}}{\partial{x}}$

# %% [markdown]
# ## Autodiff example that looks like what we have been doing

# %%
x = torch.randn([20, 1], requires_grad=True)
y = 3*x - 2

# %%
w = torch.tensor([1.], requires_grad=True)
b = torch.tensor([1.], requires_grad=True)

y_hat = w*x + b

loss = torch.sum((y_hat - y)**2)

# %%
print(loss)
# Out:
# tensor(154.9282, grad_fn=<SumBackward0>)

# %%
loss.backward()

# %%
print(w.grad, b.grad)
# Out:
# tensor([-23.1525]) tensor([87.8504])

# %% [markdown]
# ## Do it in a loop

# %%
learning_rate = 0.01

w = torch.tensor([1.], requires_grad=True)
b = torch.tensor([1.], requires_grad=True)

print(w.item(), b.item())

for i in range(10):
  
  x = torch.randn([20, 1])
  y = 3*x - 2
  
  y_hat = w*x + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

  print(w.item(), b.item())
# Out:
# 1.0 1.0
# 1.471376657485962 -0.11702954769134521
# 2.018571376800537 -0.9352603554725647
# 2.5629045963287354 -1.4710428714752197
# 2.7816545963287354 -1.7254265546798706
# 2.855975389480591 -1.843988299369812
# 2.907050848007202 -1.9017494916915894
# 2.934631586074829 -1.9403101205825806
# 2.9705216884613037 -1.9713655710220337
# 2.974573850631714 -1.977360725402832
# 2.9797449111938477 -1.9849894046783447

# %% [markdown]
# ## Do it for a large problem

# %%
# %%time
learning_rate = 0.001
N = 10000000
epochs = 200

w = torch.rand([N], requires_grad=True)
b = torch.ones([1], requires_grad=True)

# print(torch.mean(w).item(), b.item())

for i in range(epochs):
  
  x = torch.randn([N])
  y = torch.dot(3*torch.ones([N]), x) - 2
  
  y_hat = torch.dot(w, x) + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

#   print(torch.mean(w).item(), b.item())
# Out:
# CPU times: user 40.7 s, sys: 428 ms, total: 41.1 s
# Wall time: 41.2 s

# %%
# %%time
learning_rate = 0.001
N = 10000000
epochs = 200

w = torch.rand([N], requires_grad=True, device=cuda0)
b = torch.ones([1], requires_grad=True, device=cuda0)

# print(torch.mean(w).item(), b.item())

for i in range(epochs):
  
  x = torch.randn([N], device=cuda0)
  y = torch.dot(3*torch.ones([N], device=cuda0), x) - 2
  
  y_hat = torch.dot(w, x) + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

  #print(torch.mean(w).item(), b.item())
# Out:
# CPU times: user 875 ms, sys: 648 ms, total: 1.52 s
# Wall time: 1.55 s
